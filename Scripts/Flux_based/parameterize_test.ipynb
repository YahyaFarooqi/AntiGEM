# %%
import cobra
import pandas as pd
import riptide
import os

def parameterize_model(model, transcriptomic, base_filename):
    # Check if the DataFrame has at least two columns
    if transcriptomic.shape[1] < 2:
        raise ValueError(f"The file {base_filename} does not contain enough columns.")

    # Prepare abundance data
    transcriptomic = transcriptomic.iloc[:, [0, 1]]  # Adjusted to correct column indices
    transcriptomic.columns = ['gene', 'value']
    transcriptomic['gene'] = transcriptomic['gene'].astype(str)
    transcriptomic['value'] = pd.to_numeric(transcriptomic['value'], errors='coerce')

    # Check if all values are zero and skip if true
    if (transcriptomic['value'] == 0).all():
        print(f"Skipping processing for {base_filename} as all value entries are zero.")
        return None

    gene_df = pd.read_csv('/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/gene_df_subtilis.tsv', sep='\t')
    if not gene_df['gene'].isin(transcriptomic['gene']).any():
        print(f"Warning: No matching genes found in {base_filename}.")
        return None  # Exit if no genes match, prevents further errors

    filtered_gene_df = gene_df[gene_df['gene'].isin(transcriptomic['gene'])]
    merged_data = pd.merge(filtered_gene_df, transcriptomic, on='gene', how='inner')
    if merged_data.empty:
        print(f"Warning: No data left after merging in {base_filename}.")
        return None  # Exit if merging results in no data

    merged_data = merged_data.drop(columns=['gene'])

    intermediate_path = f'/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/riptide_transcripts/{base_filename}_updated_abundance.tsv'
    merged_data.to_csv(intermediate_path, sep='\t', index=False)

    # Parameterize model using Riptide
    tr = riptide.read_transcription_file(intermediate_path, header=True)
    output = riptide.maxfit(model, tr)

    return output

def save_dict_as_tsv(data_dict, output_path):
    # Handling both scalar and list-like dictionary values
    if all(isinstance(value, (int, float, str)) for value in data_dict.values()):
        df = pd.DataFrame(list(data_dict.values()), index=data_dict.keys(), columns=['Value'])
    else:
        df = pd.DataFrame(data_dict)

    df.to_csv(output_path, sep='\t', index=False)
    print(f"Data saved at {output_path}")

model = cobra.io.read_sbml_model('/Users/yahyafarooqi/Documents/Code/AntiGEM/models/subtilis_ iYO844.xml')
medium = model.medium
medium['EX_glc__D_e'] = 10
medium['EX_trp__L_e'] = 1
medium['EX_glu__L_e'] = 1
medium['EX_cit_e'] = 1
model.medium = medium

# Paths and directories setup
path = '/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/transcriptome_data/test_set'
output_directory_1 = '/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fluxes'
output_directory_2 = '/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit'
model_save_directory = '/Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/constrained_models'

# Ensure the output directories exist
os.makedirs(output_directory_1, exist_ok=True)
os.makedirs(output_directory_2, exist_ok=True)
os.makedirs(model_save_directory, exist_ok=True)

# Loop through all .tsv files in the directory
for filename in os.listdir(path):
    if filename.endswith('.tsv'):
        file_path = os.path.join(path, filename)
        transcriptomic_file = pd.read_csv(file_path, sep='\t')
        base_filename = '.'.join(filename.split('.')[:-1])

        # Assuming parameterize_model returns an object with attributes 'model' and 'concordance'
        object = parameterize_model(model, transcriptomic_file, base_filename)
        if object:
            c_model = object.model

            # Save the constrained model as an XML file
            model_save_path = os.path.join(model_save_directory, f'{base_filename}_constrained.xml')
            cobra.io.write_sbml_model(c_model, model_save_path)
            print(f"Constrained model saved as XML for {base_filename}")

            # Perform flux balance analysis
            solution = cobra.flux_analysis.pfba(c_model)
            flux_output_file_path = os.path.join(output_directory_1, f'{base_filename}_fluxes.tsv')
            solution.fluxes.to_csv(flux_output_file_path, sep='\t')
            print(f"Flux analysis results saved for {base_filename}")

            # Saving concordance dictionary
            fit_output_file_path = os.path.join(output_directory_2, f'{base_filename}_fit.tsv')
            save_dict_as_tsv(object.concordance, fit_output_file_path)
# Out:
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.05 of optimal objective flux
#
# Reactions pruned to 351 from 1250 (71.92% change)
# Metabolites pruned to 355 from 990 (64.14% change)
# Flux through the objective DECREASED to ~0.0445 from ~0.7593 (94.14% change)
# Context-specific metabolism correlates with transcriptome (r=-0.149, p=0.005 *)
#
# RIPTiDe completed in, 2 minutes and 59 seconds
#
# Constrained model saved as XML for ah1.chip7.200301
# Flux analysis results saved for ah1.chip7.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah1.chip7.200301_fit.tsv
# Skipping processing for acl2.chipXX-batch29.181201 as all value entries are zero.
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 355 from 1250 (71.6% change)
# Metabolites pruned to 360 from 990 (63.64% change)
# Flux through the objective DECREASED to ~0.1084 from ~0.7593 (85.72% change)
# Context-specific metabolism correlates with transcriptome (r=-0.138, p=0.009 *)
#
# RIPTiDe completed in, 3 minutes and 0 second
#
# Constrained model saved as XML for ah1.chip10.200301
# Flux analysis results saved for ah1.chip10.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah1.chip10.200301_fit.tsv
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 352 from 1250 (71.84% change)
# Metabolites pruned to 357 from 990 (63.94% change)
# Flux through the objective DECREASED to ~0.0901 from ~0.7593 (88.13% change)
# Context-specific metabolism correlates with transcriptome (r=-0.181, p=0.001 *)
#
# RIPTiDe completed in, 2 minutes and 53 seconds
#
# Constrained model saved as XML for ah2.chip9.200301
# Flux analysis results saved for ah2.chip9.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah2.chip9.200301_fit.tsv
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 354 from 1250 (71.68% change)
# Metabolites pruned to 359 from 990 (63.74% change)
# Flux through the objective DECREASED to ~0.1505 from ~0.7593 (80.18% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.067, n.s.)
#
# RIPTiDe completed in, 2 minutes and 59 seconds
#
# Constrained model saved as XML for al1.chip14-batch10.240401
# Flux analysis results saved for al1.chip14-batch10.240401
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/al1.chip14-batch10.240401_fit.tsv
# Skipping processing for acl1.chipVIII-batch28.111201 as all value entries are zero.
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 351 from 1250 (71.92% change)
# Metabolites pruned to 356 from 990 (64.04% change)
# Flux through the objective DECREASED to ~0.1507 from ~0.7593 (80.15% change)
# Context-specific metabolism correlates with transcriptome (r=-0.14, p=0.009 *)
#
# RIPTiDe completed in, 2 minutes and 57 seconds
#
# Constrained model saved as XML for ah1.chip5.200301
# Flux analysis results saved for ah1.chip5.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah1.chip5.200301_fit.tsv
# Skipping processing for acl1.chip20-batch24.111201 as all value entries are zero.
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.05 of optimal objective flux
#
# Reactions pruned to 350 from 1250 (72.0% change)
# Metabolites pruned to 354 from 990 (64.24% change)
# Flux through the objective DECREASED to ~0.044 from ~0.7593 (94.21% change)
# Context-specific metabolism correlates with transcriptome (r=-0.137, p=0.01 *)
#
# RIPTiDe completed in, 2 minutes and 46 seconds
#
# Constrained model saved as XML for ah2.chip6.200301
# Flux analysis results saved for ah2.chip6.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah2.chip6.200301_fit.tsv
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 361 from 1250 (71.12% change)
# Metabolites pruned to 366 from 990 (63.03% change)
# Flux through the objective DECREASED to ~0.1509 from ~0.7593 (80.13% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.044, n.s.)
#
# RIPTiDe completed in, 17 minutes and 58 seconds
#
# Constrained model saved as XML for al1.chip4-batch8.240401
# Flux analysis results saved for al1.chip4-batch8.240401
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/al1.chip4-batch8.240401_fit.tsv
# Skipping processing for acl2.chip20-batch25.111201 as all value entries are zero.
# Skipping processing for acl1.chip19-batch25.111201 as all value entries are zero.
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 359 from 1250 (71.28% change)
# Metabolites pruned to 364 from 990 (63.23% change)
# Flux through the objective DECREASED to ~0.1505 from ~0.7593 (80.18% change)
# Context-specific metabolism correlates with transcriptome (r=-0.184, p<0.001 *)
#
# RIPTiDe completed in, 2 minutes and 53 seconds
#
# Constrained model saved as XML for ah2.chip8.200301
# Flux analysis results saved for ah2.chip8.200301
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/ah2.chip8.200301_fit.tsv
# Skipping processing for acl2.chipIX-batch28.111201 as all value entries are zero.
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.05 of optimal objective flux
#
# Reactions pruned to 355 from 1250 (71.6% change)
# Metabolites pruned to 359 from 990 (63.74% change)
# Flux through the objective DECREASED to ~0.0447 from ~0.7593 (94.11% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.074, n.s.)
#
# RIPTiDe completed in, 2 minutes and 52 seconds
#
# Constrained model saved as XML for al2.chip20-batch13.240401
# Flux analysis results saved for al2.chip20-batch13.240401
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/al2.chip20-batch13.240401_fit.tsv
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.1 of optimal objective flux
#
# Reactions pruned to 358 from 1250 (71.36% change)
# Metabolites pruned to 363 from 990 (63.33% change)
# Flux through the objective DECREASED to ~0.1079 from ~0.7593 (85.79% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.077, n.s.)
#
# RIPTiDe completed in, 25 minutes and 20 seconds
#
# Constrained model saved as XML for al1.chip19-batch13.240401
# Flux analysis results saved for al1.chip19-batch13.240401
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/al1.chip19-batch13.240401_fit.tsv
# Running max fit RIPTiDe for objective fraction range: 0.1 to 0.9...
# Analyzing context-specific subnetwork flux ranges...
# Progress: 100%
#
# Testing local objective fractions to 0.1...
# Progress: 100%
#
# Context-specific metabolism fit with 0.05 of optimal objective flux
#
# Reactions pruned to 351 from 1250 (71.92% change)
# Metabolites pruned to 356 from 990 (64.04% change)
# Flux through the objective DECREASED to ~0.0446 from ~0.7593 (94.13% change)
# Context-specific metabolism does not correlate with transcriptome (r=-0.089, n.s.)
#
# RIPTiDe completed in, 2 minutes and 50 seconds
#
# Constrained model saved as XML for al2.chip9-batch8.240401
# Flux analysis results saved for al2.chip9-batch8.240401
# Data saved at /Users/yahyafarooqi/Documents/Code/AntiGEM/Data/intermediate/c_fit/al2.chip9-batch8.240401_fit.tsv
