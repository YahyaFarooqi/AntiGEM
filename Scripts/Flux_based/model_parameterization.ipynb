# %% [markdown]
# Begin by loading model and approximating Belitzky's minimal medium.

# %%
## Preparing the GSM data ##
import pandas as pd
import cobra 
from IPython.display import display

# Load the model

model = cobra.io.read_sbml_model('../../models/subtilis_ iYO844.xml')

medium = model.medium
medium['EX_glu__L_e'] = 1
medium['EX_trp__L_e'] = 1
medium['EX_cit_e'] = 1
model.medium = medium


model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_BS_10 = 0.25000270418329434</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.0008013</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cit_e</td>
#       <td>EX_cit_e</td>
#       <td>1</td>
#       <td>6</td>
#       <td>28.10%</td>
#     </tr>
#     <tr>
#       <td>fe3_e</td>
#       <td>EX_fe3_e</td>
#       <td>0.0008625</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>1.7</td>
#       <td>6</td>
#       <td>47.78%</td>
#     </tr>
#     <tr>
#       <td>glu__L_e</td>
#       <td>EX_glu__L_e</td>
#       <td>1</td>
#       <td>5</td>
#       <td>23.42%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>3.4</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e</td>
#       <td>0.1766</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e</td>
#       <td>0.02543</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>0.9755</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>9.832</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.3837</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e</td>
#       <td>0.04258</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>trp__L_e</td>
#       <td>EX_trp__L_e</td>
#       <td>0.01358</td>
#       <td>11</td>
#       <td>0.70%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-12.41</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-12.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lets get our gene protein reaction rules into a formate we can use to assess the mapping to our gene abundance data.

# %%
rxn_gene_dict = {rxn.id: rxn.gene_name_reaction_rule for rxn in model.reactions}

# make it into a dataframe

rxn_gene_df = pd.DataFrame(rxn_gene_dict.items(), columns=['rxn_id', 'gene_names'])

#filter out reactions with no gene names

rxn_gene_df = rxn_gene_df[rxn_gene_df['gene_names'] != '']

df = rxn_gene_df

def parse_genes(genes):
    # Replace logical connectors with commas, and remove parentheses
    genes = genes.replace(' and ', ', ').replace(' or ', ', ').replace('(', '').replace(')', '')
    # Split on commas and strip extra spaces, then deduplicate
    genes = set([gene.strip() for gene in genes.split(',')])
    return ', '.join(sorted(genes))

# Apply the function to clean up gene names
df['gene_names'] = df['gene_names'].apply(parse_genes)

# If needed, aggregate by 'rxn_id' (if there are duplicate 'rxn_id' values)
df = df.groupby('rxn_id')['gene_names'].agg(lambda x: ', '.join(sorted(set(', '.join(x).split(', '))))).reset_index()

print(df.head(50))
# Out:
#        rxn_id                                gene_names
# 0     23CN2P1                                      yfkN
# 1     23CN2P2                                      yfkN
# 2     23CN2P3                                      yfkN
# 3     23CN2P4                                      yfkN
# 4      26DPAi                            spoVFA, spoVFB
# 5     2S6HCCi                                      menD
# 6     3AMBAt2                                      gabP
# 7     3NUCLE1                                      yfkN
# 8     3NUCLE2                                      yfkN
# 9     3NUCLE3                                      yfkN
# 10    3NUCLE4                                      yfkN
# 11    AAMYL_1                                      amyE
# 12     AB6PGH                                bglA, licH
# 13       ABTA                                      gabT
# 14      ABUTD                          aldX, aldY, dhaS
# 15    ABUTt2r                                      gabP
# 16    ACACT1r                                      mmgA
# 17    ACACT2r                                      fadA
# 18    ACACT3r                                      fadA
# 19    ACACT4r                                      fadA
# 20  ACACT5r_1                                      fadA
# 21  ACACT6r_1                                      fadA
# 22    ACACT7r                                      fadA
# 23     ACCOAC              accA, accB, accC, accD, birA
# 24    ACGApts                          nagP, ptsH, ptsI
# 25       ACGK                                      argB
# 26       ACGS                                      argJ
# 27      ACHBS                          alsS, ilvB, ilvH
# 28       ACKr                                      ackA
# 29      ACLDC                                      alsD
# 30       ACLS                          alsS, ilvB, ilvH
# 31     ACOAD1              acdA, fadE, mmgC, ydbM, yngJ
# 32     ACOAD2                                acdA, mmgC
# 33    ACOAD20                          fadE, ydbM, yngJ
# 34     ACOAD3                                acdA, mmgC
# 35   ACOAD4_1                                acdA, mmgC
# 36   ACOAD5_1                                acdA, mmgC
# 37     ACOAD6                                acdA, mmgC
# 38     ACOAD7                                acdA, mmgC
# 39    ACOADH2                          fadE, ydbM, yngJ
# 40    ACODA_1                                      thiQ
# 41      ACONT                                      citB
# 42      ACOTA                                      argD
# 43      ACPS1                                      acpS
# 44     ACPpds                                      rtbJ
# 45        ACS                                      acsA
# 46       ACS2                                      acsA
# 47      ACTD2  acoA, acoB, acoC, acoL, acuA, acuB, acuC
# 48    ACTNabc              ytrB, ytrC, ytrD, ytrE, ytrF
# 49   ACTNabc1              ytrB, ytrC, ytrD, ytrE, ytrF

# %% [markdown]
# Now load in the abundance data and format so it is mappable to the previous dataframe.

# %%
abundance = pd.read_excel('/Users/yahyafarooqi/Documents/AntiGEM/Data/intermediate/gene_set.xlsx')


display(abundance.head())
# Out:
#   GeneID  Abundance
# 0   ybdT   0.994016
# 1   ybxH   0.856044
# 2   ybdM   0.963332
# 3   ybdK   1.004663
# 4   ybxF   1.000806

# %%
# if geneID in abundance is in gene_names in df, add label "match" to geneID in abundance, if not add label "no_match"


def match_genes(genes, abundance):
    genes = set(genes.split(', '))
    return 'match' if genes & set(abundance['GeneID']) else 'no_match'

df['match'] = df['gene_names'].apply(match_genes, abundance=abundance)

#print(df.head(50))

# %%
# print the number of genes that match and do not match
print(df['match'].value_counts())
# Out:
# match
# match       600
# no_match    304
# Name: count, dtype: int64

# %%
fluxes = model.optimize().fluxes

# filter by active reactions

print(len(fluxes))

short_fluxes = fluxes[fluxes.abs() > 1e-6]

print(len(short_fluxes))

print(short_fluxes.head())

#append these flux columns to the dataframe by reaction ID (first columb), so that flux value is added to the corresponding reaction ID

df_new = df.merge(short_fluxes.rename('flux'), left_on='rxn_id', right_index=True, how='left')  

#filter all rows with no flux value (NaN)

df_new = df_new[~df_new['flux'].isnull()]

#filter by match

df_new = df_new[df_new['match'] == 'match']

display(df_new.head(50))

print(len(df_new))
# Out:
# 1250
# 337
# EX_fe3_e      -0.000863
# EX_glc__D_e   -1.700000
# EX_glu__L_e   -1.000000
# EX_ca2_e      -0.000801
# EX_cit_e      -1.000000
# Name: fluxes, dtype: float64
#         rxn_id                                         gene_names  match  \
# 5      2S6HCCi                                               menD  match
# 16     ACACT1r                                               mmgA  match
# 23      ACCOAC                       accA, accB, accC, accD, birA  match
# 25        ACGK                                               argB  match
# 27       ACHBS                                   alsS, ilvB, ilvH  match
# 28        ACKr                                               ackA  match
# 29       ACLDC                                               alsD  match
# 30        ACLS                                   alsS, ilvB, ilvH  match
# 31      ACOAD1                       acdA, fadE, mmgC, ydbM, yngJ  match
# 32      ACOAD2                                         acdA, mmgC  match
# 34      ACOAD3                                         acdA, mmgC  match
# 35    ACOAD4_1                                         acdA, mmgC  match
# 36    ACOAD5_1                                         acdA, mmgC  match
# 37      ACOAD6                                         acdA, mmgC  match
# 38      ACOAD7                                         acdA, mmgC  match
# 41       ACONT                                               citB  match
# 42       ACOTA                                               argD  match
# 47       ACTD2           acoA, acoB, acoC, acoL, acuA, acuB, acuC  match
# 51        ADCL                                               pabC  match
# 52        ADCS                                         pabA, pabB  match
# 54        ADK1                                                adk  match
# 63      ADSL1r                                               purB  match
# 64      ADSL2r                                               purB  match
# 65        ADSS                                               purA  match
# 69        AGPR                                               argC  match
# 74      AICART                                               purH  match
# 75       AIRC1                                         purE, purK  match
# 76       AKGDH                                   odhA, odhB, pdhD  match
# 78        AKP1                                         phoA, phoB  match
# 82     ALATA_L                                               yugH  match
# 122       APSR                                               cysH  match
# 131      ARGSL                                               argH  match
# 132      ARGSS                                               argG  match
# 139       ASAD                                                asd  match
# 141      ASNS1                                   asnB, asnH, asnO  match
# 143      ASPCT                                               pyrB  match
# 144       ASPK                                   dapG, lysC, yclM  match
# 146      ASPO6                                               nadB  match
# 148      ASPTA                                               aspB  match
# 149     ATPPRT                                               hisG  match
# 150     ATPS4r  atpA, atpB, atpC, atpD, atpE, atpF, atpG, atpH...  match
# 164        CAT                                   katA, katE, katX  match
# 165       CAt4                                               yfkE  match
# 167       CBPS                           carA, carB, pyrAA, pyrAB  match
# 170   CDGPT_BS                                               pgsA  match
# 171  CDPDSP_BS                                               pssA  match
# 178      CHORM                                   aroH, aroX, yszB  match
# 179      CHORS                                               aroF  match
# 186     CITt2r                                         cimH, yraO  match
# 187  CLPNS2_BS                                   clsA, clsB, ywiE  match
#
#           flux
# 5     0.000067
# 16    0.006994
# 23    0.254477
# 25    0.048256
# 27    0.094915
# 28    0.106779
# 29    0.004283
# 30    0.185334
# 31    0.006994
# 32    0.006994
# 34   -0.006994
# 35   -0.006994
# 36   -0.006994
# 37   -0.006994
# 38   -0.005380
# 41    3.427106
# 42   -0.048256
# 47    0.004283
# 51    0.000092
# 52    0.000092
# 54    0.378131
# 63    0.045694
# 64    0.045538
# 65    0.045694
# 69   -0.048256
# 74    0.065973
# 75    0.045538
# 76    4.182897
# 78    0.000092
# 82   -0.180294
# 122   0.042579
# 131   0.048256
# 132   0.048256
# 139  -0.276605
# 141   0.036997
# 143   0.030494
# 144   0.276605
# 146   0.004329
# 148  -0.524917
# 149   0.020435
# 150  32.499762
# 164   0.017457
# 165  -0.000801
# 167   0.078750
# 170   0.005200
# 171   0.014000
# 178   0.071692
# 179   0.071850
# 186   1.000000
# 187   0.000125
# 215
