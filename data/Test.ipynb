# %%
## Preparing the abundance data ##


import pandas as pd

# Load data
df3 = pd.read_csv('/Users/nfarooqi/masters-thesis-evolvey/space-evolvey/code/evolvey_analysis/Testerosa/data/mmc1_Table.S3.txt', sep='\t')

# Replace '-' with 0 and fill NaN with 0
df3 = df3.replace('-', 0)
df3 = df3.fillna(0)

# Drop the second column
df3 = df3.drop(df3.columns[1], axis=1)

# Convert columns to numeric, except the first column, handling non-numeric values
df3.iloc[:, 1:] = df3.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').fillna(0)

# Normalize each column by the column's maximum value
df3.iloc[:, 1:] = df3.iloc[:, 1:].div(df3.iloc[:, 1:].max())

# Now substract all values from 1 to invert the values

df3.iloc[:, 1:] = 1 - df3.iloc[:, 1:]

# Display the result
print(df3.head())
# Out:
#    Name SvL1chip71-batch41.280602 PheH1.chip37-batch47.181002  \
# 0  ybeF                  0.983924                         1.0
# 1  glpQ                  0.981708                    0.871917
# 2  ybdT                  0.948823                     0.43833
# 3  ybxH                  0.985057                     0.88425
# 4  ybdM                  0.977327                    0.886148
#
#   ah1.chip5.200301 ah1.chip7.200301 ah1.chip10.200301 ah2.chip6.200301  \
# 0         0.683299         0.686465          0.785778         0.849071
# 1         0.696497         0.724377          0.768707         0.864026
# 2         0.682857         0.678485          0.753008         0.833862
# 3         0.703401         0.709461          0.778522         0.795993
# 4         0.697551         0.708653          0.768628         0.781421
#
#   ah2.chip8.200301 ah2.chip9.200301 al2.chip9-batch8.240401  ...  \
# 0         0.831115              1.0                0.819421  ...
# 1         0.855892         0.840113                0.836632  ...
# 2         0.812268              1.0                0.823492  ...
# 3          0.79368         0.777358                0.791322  ...
# 4         0.771375         0.762264                0.754132  ...
#
#   etl2.chip14-batch27.101201 etl1.chip14-batch26.101201  \
# 0                        1.0                        1.0
# 1                        1.0                        1.0
# 2                        1.0                        1.0
# 3                        1.0                        1.0
# 4                        1.0                        1.0
#
#   etl1.chipXXII-batch26.101201 etl2.chip15-batch26.101201  \
# 0                          1.0                        1.0
# 1                          1.0                        1.0
# 2                          1.0                        1.0
# 3                          1.0                        1.0
# 4                          1.0                        1.0
#
#   etl2.chipXXIII-batch28.101201 NtH1.chip28-batch45.051102  \
# 0                           1.0                        1.0
# 1                           1.0                        1.0
# 2                           1.0                        1.0
# 3                           1.0                        1.0
# 4                           1.0                        1.0
#
#   NtH1.chip49-batch41.071002 NtH2.chip50-batch41.071002  \
# 0                        1.0                        1.0
# 1                        1.0                        1.0
# 2                        1.0                        1.0
# 3                        1.0                        1.0
# 4                        1.0                        1.0
#
#   NtL1.chip51-batch41.071002 NtL2.chip53-batch41.071002
# 0                        1.0                        1.0
# 1                        1.0                        1.0
# 2                        1.0                        1.0
# 3                        1.0                        1.0
# 4                        1.0                        1.0
#
# [5 rows x 310 columns]

# %%
## Preparing the GSM data ##

import cobra 

# Load the model

model = cobra.io.read_sbml_model('/Users/nfarooqi/masters-thesis-evolvey/space-evolvey/code/evolvey_analysis/Testerosa/models/subtilis.xml')


rxn_gene_dict = {rxn.id: rxn.gene_name_reaction_rule for rxn in model.reactions}

# make it into a dataframe

rxn_gene_df = pd.DataFrame(rxn_gene_dict.items(), columns=['rxn_id', 'gene_names'])

#filter out reactions with no gene names

rxn_gene_df = rxn_gene_df[rxn_gene_df['gene_names'] != '']

df = rxn_gene_df

def parse_genes(genes):
    # Replace logical connectors with commas, and remove parentheses
    genes = genes.replace(' and ', ', ').replace(' or ', ', ').replace('(', '').replace(')', '')
    # Split on commas and strip extra spaces, then deduplicate
    genes = set([gene.strip() for gene in genes.split(',')])
    return ', '.join(sorted(genes))

# Apply the function to clean up gene names
df['gene_names'] = df['gene_names'].apply(parse_genes)

# If needed, aggregate by 'rxn_id' (if there are duplicate 'rxn_id' values)
df = df.groupby('rxn_id')['gene_names'].agg(lambda x: ', '.join(sorted(set(', '.join(x).split(', '))))).reset_index()

print(df.head(50))
# Out:
#         rxn_id                                         gene_names
# 179    2S6HCCi                                               menD
# 180     26DPAi                                  spoVFA and spoVFB
# 181    3AMBAt2                                               gabP
# 182        FDH  (fdhD and yjgC) or (fdhD and yrhE) or (fdhD an...
# 183     FDMO_1                                               ssuD
# 185    AAMYL_1                                               amyE
# 189       ABTA                                               gabT
# 193        FBA                                       iolJ or fbaA
# 195       FBA2                                       fbaA or iolJ
# 196        FBP                                                fbp
# 197     FCLT_2                                               hemH
# 198      FDMO1                                               ssuD
# 199    FDMO2_1                                               ssuD
# 200    FDMO3_1                                               ssuD
# 201     AB6PGH                                       licH or bglA
# 202      ABUTD                               dhaS or aldY or aldX
# 203    MACCOAT                                               fadA
# 204    ACACT2r                                               fadA
# 205    ACACT3r                                               fadA
# 206    ACACT4r                                               fadA
# 207  ACACT5r_1                                               fadA
# 208  ACACT6r_1                                               fadA
# 209    ACACT7r                                               fadA
# 210    FDMO4_1                                               ssuD
# 211    FDMO5_1                                               ssuD
# 212    FDMO6_1                                               ssuD
# 213    ACACT1r                                               mmgA
# 214     ACCOAC         (accA and accD) and accB and accC and birA
# 216    ACGApts                             nagP and ptsH and ptsI
# 217       ACGK                                               argB
# 218     FE2abc                             feuA and feuB and feuC
# 220       ACGS                                               argJ
# 222      FOLD3                                               folP
# 232       ACKr                                               ackA
# 233      ACLDC                                               alsD
# 237    ACODA_1                                               thiQ
# 238    ACOAD20                               yngJ or fadE or ydbM
# 241      ACONT                                               citB
# 242     ACOAD2                                       acdA or mmgC
# 244     ACOAD1               fadE or mmgC or acdA or yngJ or ydbM
# 245    ACOADH2                               ydbM or yngJ or fadE
# 248      ACOTA                                               argD
# 252      ACPS1                                               acpS
# 255      APATi                                               dapH
# 259     APRAUR                                               ribD
# 260       APSR                                               cysH
# 261     ACPpds                                               rtbJ
# 262        ACS                                               acsA
# 264       ALKP                                       phoA or phoB
# 265     APTA1i                                               dapX

# %%
import pandas as pd

# Assuming df and df3 are already defined and df3 is set with 'Name' as the index
df3.set_index('Name', inplace=True)

# Function to retrieve expression values for genes
def get_expression_values(gene_list, col):
    values = []
    genes = gene_list.split(', ')
    for gene in genes:
        if gene in df3.index:
            value = df3.at[gene, col]  # Retrieve the value for the gene
            values.append(str(value))
    return ', '.join(values)

# Prepare a dictionary to hold the new columns data
new_columns = {}

# Loop over each column in df3 (except the index 'Name')
for col in df3.columns:
    # Apply the function to each row in df and store results in the dictionary
    new_columns[col] = df['gene_names'].apply(lambda x: get_expression_values(x, col))

# Create a new DataFrame from the dictionary
new_df = pd.DataFrame(new_columns)

# Concatenate this new DataFrame with the original df
df = pd.concat([df, new_df], axis=1)

print(df)
# Out:
#       rxn_id        gene_names  \
# 0    23CN2P1              yfkN
# 1    23CN2P2              yfkN
# 2    23CN2P3              yfkN
# 3    23CN2P4              yfkN
# 4     26DPAi    spoVFA, spoVFB
# ..       ...               ...
# 899    XYLI2              xylA
# 900     XYLK              xylB
# 901    XYLt2              araE
# 902    ZN2t4              czcD
# 903    ZNabc  znuA, znuB, znuC
#
#                              SvL1chip71-batch41.280602  \
# 0    Name\nyfkN    0.977327\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.977327\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.977327\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.977327\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.984008\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    1.0\nxylA    1.0\nName: SvL1chip...
# 900  Name\nxylB    0.97452\nxylB        1.0\nName: ...
# 901  Name\naraE    0.987888\naraE         1.0\nName...
# 902  Name\nczcD    1.0\nczcD    1.0\nName: SvL1chip...
# 903
#
#                            PheH1.chip37-batch47.181002  \
# 0    Name\nyfkN    0.908178\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.908178\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.908178\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.908178\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.859583\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    1.0\nxylA    1.0\nName: PheH1.ch...
# 900  Name\nxylB    0.895636\nxylB         1.0\nName...
# 901  Name\naraE    0.902277\naraE         1.0\nName...
# 902  Name\nczcD    0.916148\nczcD         1.0\nName...
# 903
#
#                                       ah1.chip5.200301  \
# 0    Name\nyfkN    0.632653\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.632653\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.632653\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.632653\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.615646\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    0.64966\nxylA        1.0\nName: ...
# 900  Name\nxylB    0.659864\nxylB         1.0\nName...
# 901  Name\naraE    1.0\naraE    1.0\nName: ah1.chip...
# 902  Name\nczcD    0.66534\nczcD        1.0\nName: ...
# 903
#
#                                       ah1.chip7.200301  \
# 0    Name\nyfkN    0.643098\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.643098\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.643098\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.643098\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.589226\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    0.653199\nxylA         1.0\nName...
# 900  Name\nxylB    0.649832\nxylB         1.0\nName...
# 901  Name\naraE    0.725017\naraE         1.0\nName...
# 902  Name\nczcD    0.626263\nczcD         1.0\nName...
# 903
#
#                                      ah1.chip10.200301  \
# 0    Name\nyfkN    0.699208\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.699208\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.699208\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.699208\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.709763\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    0.722955\nxylA         1.0\nName...
# 900  Name\nxylB    0.728232\nxylB         1.0\nName...
# 901  Name\naraE    0.791847\naraE         1.0\nName...
# 902  Name\nczcD    0.720317\nczcD         1.0\nName...
# 903
#
#                                       ah2.chip6.200301  \
# 0    Name\nyfkN    1.0\nyfkN    1.0\nName: ah2.chip...
# 1    Name\nyfkN    1.0\nyfkN    1.0\nName: ah2.chip...
# 2    Name\nyfkN    1.0\nyfkN    1.0\nName: ah2.chip...
# 3    Name\nyfkN    1.0\nyfkN    1.0\nName: ah2.chip...
# 4    Name\nspoVFA    0.808743\nspoVFA         1.0\n...
# ..                                                 ...
# 899  Name\nxylA    0.783242\nxylA         1.0\nName...
# 900  Name\nxylB    0.801457\nxylB         1.0\nName...
# 901  Name\naraE    1.0\naraE    1.0\nName: ah2.chip...
# 902  Name\nczcD    0.76867\nczcD        1.0\nName: ...
# 903
#
#                                       ah2.chip8.200301  \
# 0    Name\nyfkN    0.804833\nyfkN         1.0\nName...
# 1    Name\nyfkN    0.804833\nyfkN         1.0\nName...
# 2    Name\nyfkN    0.804833\nyfkN         1.0\nName...
# 3    Name\nyfkN    0.804833\nyfkN         1.0\nName...
# 4    Name\nspoVFA    0.80855\nspoVFA        1.0\nNa...
# ..                                                 ...
# 899  Name\nxylA    0.780669\nxylA         1.0\nName...
# 900  Name\nxylB    0.782528\nxylB         1.0\nName...
# 901  Name\naraE    0.85842\naraE        1.0\nName: ...
# 902  Name\nczcD    0.758364\nczcD         1.0\nName...
# 903
#
#                                       ah2.chip9.200301  ...  \
# 0    Name\nyfkN    0.792453\nyfkN         1.0\nName...  ...
# 1    Name\nyfkN    0.792453\nyfkN         1.0\nName...  ...
# 2    Name\nyfkN    0.792453\nyfkN         1.0\nName...  ...
# 3    Name\nyfkN    0.792453\nyfkN         1.0\nName...  ...
# 4    Name\nspoVFA    0.777358\nspoVFA         1.0\n...  ...
# ..                                                 ...  ...
# 899  Name\nxylA    0.749057\nxylA         1.0\nName...  ...
# 900  Name\nxylB    0.788679\nxylB         1.0\nName...  ...
# 901  Name\naraE    0.866264\naraE         1.0\nName...  ...
# 902  Name\nczcD    0.756604\nczcD         1.0\nName...  ...
# 903                                                     ...
#
#                             etl2.chip14-batch27.101201  \
# 0    Name\nyfkN         1.0\nyfkN    0.885693\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.885693\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.885693\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.885693\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.867574\n...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.808168\nName...
# 900  Name\nxylB         1.0\nxylB    0.866337\nName...
# 901  Name\naraE         1.0\naraE    0.867574\nName...
# 902  Name\nczcD    1.0\nczcD    1.0\nName: etl2.chi...
# 903
#
#                             etl1.chip14-batch26.101201  \
# 0    Name\nyfkN         1.0\nyfkN    0.900553\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.900553\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.900553\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.900553\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.856265\n...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.911253\nName...
# 900  Name\nxylB         1.0\nxylB    0.874693\nName...
# 901  Name\naraE         1.0\naraE    0.863636\nName...
# 902  Name\nczcD         1.0\nczcD    0.894017\nName...
# 903
#
#                           etl1.chipXXII-batch26.101201  \
# 0    Name\nyfkN         1.0\nyfkN    0.890397\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.890397\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.890397\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.890397\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.843424\n...
# ..                                                 ...
# 899  Name\nxylA    1.0\nxylA    1.0\nName: etl1.chi...
# 900  Name\nxylB         1.0\nxylB    0.916764\nName...
# 901  Name\naraE         1.0\naraE    0.870564\nName...
# 902  Name\nczcD    1.0\nczcD    1.0\nName: etl1.chi...
# 903
#
#                             etl2.chip15-batch26.101201  \
# 0    Name\nyfkN        1.0\nyfkN    0.87458\nName: ...
# 1    Name\nyfkN        1.0\nyfkN    0.87458\nName: ...
# 2    Name\nyfkN        1.0\nyfkN    0.87458\nName: ...
# 3    Name\nyfkN        1.0\nyfkN    0.87458\nName: ...
# 4    Name\nspoVFA         1.0\nspoVFA    0.853303\n...
# ..                                                 ...
# 899  Name\nxylA    1.0\nxylA    1.0\nName: etl2.chi...
# 900  Name\nxylB         1.0\nxylB    0.940022\nName...
# 901  Name\naraE         1.0\naraE    0.870101\nName...
# 902  Name\nczcD    1.0\nczcD    1.0\nName: etl2.chi...
# 903
#
#                          etl2.chipXXIII-batch28.101201  \
# 0    Name\nyfkN         1.0\nyfkN    0.906538\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.906538\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.906538\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.906538\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.883284\n...
# ..                                                 ...
# 899  Name\nxylA    1.0\nxylA    1.0\nName: etl2.chi...
# 900  Name\nxylB         1.0\nxylB    0.902384\nName...
# 901  Name\naraE         1.0\naraE    0.897132\nName...
# 902  Name\nczcD    1.0\nczcD    1.0\nName: etl2.chi...
# 903
#
#                             NtH1.chip28-batch45.051102  \
# 0    Name\nyfkN         1.0\nyfkN    0.882229\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.882229\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.882229\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.882229\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.904585\n...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.932292\nName...
# 900  Name\nxylB         1.0\nxylB    0.883281\nName...
# 901  Name\naraE         1.0\naraE    0.892744\nName...
# 902  Name\nczcD         1.0\nczcD    0.873817\nName...
# 903
#
#                             NtH1.chip49-batch41.071002  \
# 0    Name\nyfkN         1.0\nyfkN    0.960046\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.960046\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.960046\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.960046\nName...
# 4    Name\nspoVFA        1.0\nspoVFA    0.96511\nNa...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.963512\nName...
# 900  Name\nxylB         1.0\nxylB    0.962987\nName...
# 901  Name\naraE         1.0\naraE    0.953957\nName...
# 902  Name\nczcD         1.0\nczcD    0.963999\nName...
# 903
#
#                             NtH2.chip50-batch41.071002  \
# 0    Name\nyfkN         1.0\nyfkN    0.920534\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.920534\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.920534\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.920534\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.942871\n...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.935615\nName...
# 900  Name\nxylB         1.0\nxylB    0.945835\nName...
# 901  Name\naraE         1.0\naraE    0.918213\nName...
# 902  Name\nczcD         1.0\nczcD    0.937355\nName...
# 903
#
#                             NtL1.chip51-batch41.071002  \
# 0    Name\nyfkN         1.0\nyfkN    0.967545\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.967545\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.967545\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.967545\nName...
# 4    Name\nspoVFA        1.0\nspoVFA    0.96198\nNa...
# ..                                                 ...
# 899  Name\nxylA        1.0\nxylA    0.97154\nName: ...
# 900  Name\nxylB         1.0\nxylB    0.969331\nName...
# 901  Name\naraE         1.0\naraE    0.964602\nName...
# 902  Name\nczcD         1.0\nczcD    0.968407\nName...
# 903
#
#                             NtL2.chip53-batch41.071002
# 0    Name\nyfkN         1.0\nyfkN    0.986844\nName...
# 1    Name\nyfkN         1.0\nyfkN    0.986844\nName...
# 2    Name\nyfkN         1.0\nyfkN    0.986844\nName...
# 3    Name\nyfkN         1.0\nyfkN    0.986844\nName...
# 4    Name\nspoVFA         1.0\nspoVFA    0.976477\n...
# ..                                                 ...
# 899  Name\nxylA         1.0\nxylA    0.986621\nName...
# 900  Name\nxylB         1.0\nxylB    0.988751\nName...
# 901  Name\naraE        1.0\naraE    0.98561\nName: ...
# 902  Name\nczcD         1.0\nczcD    0.988701\nName...
# 903
#
# [904 rows x 311 columns]
